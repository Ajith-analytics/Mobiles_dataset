# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Mobiles_Dataset.csv')
df
# Out:
#         Brand                        Product Name  Actual price  \
# 0       Apple     Apple iPhone 15 (Green, 128 GB)       79600.0
# 1       Apple      Apple iPhone 15 (Blue, 128 GB)       79600.0
# 2       Apple     Apple iPhone 15 (Black, 128 GB)       79600.0
# 3     OnePlus  OnePlus N20 SE (JADE WAVE, 128 GB)       19999.0
# 4     OnePlus  OnePlus N20 SE (BLUE OASIS, 64 GB)       16999.0
# ..        ...                                 ...           ...
# 979  Kechaoda                        Kechaoda A27        1499.0
# 980  Kechaoda                        Kechaoda A27        1499.0
# 981  Kechaoda                        Kechaoda A27        1499.0
# 982  Kechaoda                        Kechaoda A27        1499.0
# 983  Kechaoda                        Kechaoda A27        1499.0
#
#      Discount price  Discount Discount%  Stars          Rating        Reviews  \
# 0           65999.0   13601.0       17%    4.6  44,793 Ratings  2,402 Reviews
# ...

# %%
df.head(2)
# Out:
#    Brand                     Product Name  Actual price  Discount price  \
# 0  Apple  Apple iPhone 15 (Green, 128 GB)       79600.0         65999.0
# 1  Apple   Apple iPhone 15 (Blue, 128 GB)       79600.0         65999.0
#
#    Discount Discount%  Stars          Rating        Reviews RAM (GB)  \
# 0   13601.0       17%    4.6  44,793 Ratings  2,402 Reviews      NIL
# 1   13601.0       17%    4.6  44,793 Ratings  2,402 Reviews      NIL
#
#   Storage (GB)  Display Size (inch)       Camera  \
# 0          128                  6.1  48MP + 12MP
# 1          128                  6.1  48MP + 12MP
#
#                                          Description  \
# 0  128 GB ROM15.49 cm (6.1 inch) Super Retina XDR...
# 1  128 GB ROM15.49 cm (6.1 inch) Super Retina XDR...
#
#                                                 Link
# 0  https://www.flipkart.com/apple-iphone-15-green...
# 1  https://www.flipkart.com/apple-iphone-15-blue-...

# %%
df.describe()
# Out:
#         Actual price  Discount price       Stars  Display Size (inch)
# count     960.000000      980.000000  984.000000           984.000000
# mean    25866.338542    21524.410204    4.254980             6.043116
# std     22736.238534    20843.536309    0.199734             1.581261
# min      1199.000000      809.000000    3.400000             0.660000
# 25%     11999.000000     8999.000000    4.200000             6.500000
# 50%     19999.000000    15999.000000    4.300000             6.670000
# 75%     32999.000000    27444.000000    4.400000             6.720000
# max    177999.000000   176999.000000    5.000000             7.820000

# %%
for col in Data.columns:
    pct_missing = np.mean(df[col].isnull())
    print ('{}-{}%'.format(col,pct_missing))
# Out:
# Brand-0.0%
# Product Name-0.0%
# Actual price-0.024390243902439025%
# Discount price-0.0040650406504065045%
# Discount-0.0%
# Discount%-0.0%
# Stars-0.0%
# Rating-0.0%
# Reviews-0.0%
# RAM (GB)-0.0%
# Storage (GB)-0.0%
# Display Size (inch)-0.0%
# Camera-0.07723577235772358%
# Description-0.0%
# Link-0.0%

# %%
df.dtypes
# Out:
# Brand                   object
# Product Name            object
# Actual price           float64
# Discount price         float64
# Discount               float64
# Discount%               object
# Stars                  float64
# Rating                  object
# Reviews                 object
# RAM (GB)                object
# Storage (GB)            object
# Display Size (inch)    float64
# Camera                  object
# Description             object
# Link                    object
# dtype: object

# %%
df.keys()
# Out:
# Index(['Brand', 'Product Name', 'Actual price', 'Discount price', 'Discount',
#        'Discount%', 'Stars', 'Rating', 'Reviews', 'RAM (GB)', 'Storage (GB)',
#        'Display Size (inch)', 'Camera', 'Description', 'Link'],
#       dtype='object')

# %%
df['Product Name'].value_counts()
# Out:
# Product Name
# OPPO K12x 5G with 45W SUPERVOOC Charger In-The-Box (Breeze Blue, 256 GB)    31
# Nokia 105 Single SIM, Keypad Mobile Phone with Wireless FM Radio             7
# Kechaoda A27                                                                 6
# itel it5330 | 2.8 inch Big Display | 1900 mAh Battery | Kingvoice            6
# REDMI Note 13 Pro 5G (Coral Purple, 256 GB)                                  5
#                                                                             ..
# POCO F6 5G (Black, 512 GB)                                                   1
# OPPO Reno8T 5G (Sunrise Gold, 128 GB)                                        1
# OnePlus Nord CE4 lite 5G (SUPER SILVER, 256 GB)                              1
# IQOO Z9X (Storm Grey, 128 GB)                                                1
# Apple iPhone 15 (Green, 128 GB)                                              1
# Name: count, Length: 657, dtype: int64

# %%
df['Brand'].value_counts()
# Out:
# Brand
# realme       124
# REDMI        104
# SAMSUNG      100
# vivo          91
# OPPO          72
# POCO          62
# Motorola      58
# Infinix       51
# itel          48
# Apple         39
# OnePlus       38
# LAVA          32
# Nokia         30
# Tecno         23
# IQOO          20
# Kechaoda      20
# Google        15
# Nothing       10
# KARBONN        9
# Xiaomi         8
# MOTOROLA       6
# CMF            6
# Micromax       4
# I              3
# BlackZone      3
# Vox            2
# Honor          2
# Jio            2
# Samsung        2
# Name: count, dtype: int64

# %%
df[ 'Actual price'].sum()
# Out:
# 24831685.0

# %%
df[df['Brand']=='vivo'][['Brand','Discount price']].head(3)
# Out:
#    Brand  Discount price
# 9   vivo         20999.0
# 10  vivo         19999.0
# 61  vivo         24999.0

# %%
df[ (df['Brand']=='vivo') & (df['Discount'] >=1000)][['Brand','Discount']]
# Out:
#     Brand  Discount
# 9    vivo    5000.0
# 10   vivo    4000.0
# 61   vivo    1000.0
# 62   vivo    1000.0
# 67   vivo    5000.0
# ..    ...       ...
# 899  vivo    4321.0
# 900  vivo    2000.0
# 918  vivo    3310.0
# 955  vivo   35991.0
# 956  vivo   35991.0
#
# [91 rows x 2 columns]

# %%
plt.figure(figsize=(15,5))
df['Discount'].plot(kind='hist')
plt.show()

# %%
sns.scatterplot(x='Stars',y='Discount',data=df,hue="Brand")
plt.grid()
plt.show()

# %%
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df['Discount'].plot(kind='box')
plt.show()

# %%
sns.distplot(df['Stars'])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11880\1888249425.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Stars'])
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.distplot(df['Discount'])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11880\3176752206.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Discount'])
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.regplot(x='Actual price', y='Discount price',data=df)
# Out:
# <Axes: xlabel='Actual price', ylabel='Discount price'>
